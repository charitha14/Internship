# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
hr_data=pd.read_csv(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\ibm-hr-analytics-employee-attrition-performance\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %% [markdown]
# # EDA

# %%
hr_data.sample(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 164    27        No         Non-Travel       1450  Research & Development
# 399    31        No      Travel_Rarely        329  Research & Development
# 636    35       Yes  Travel_Frequently        130  Research & Development
# 308    58        No         Non-Travel        390  Research & Development
# 1317   27        No  Travel_Frequently       1297  Research & Development
# 836    29       Yes      Travel_Rarely        408                   Sales
# 254    29        No      Travel_Rarely       1247                   Sales
# 187    55        No      Travel_Rarely        692  Research & Development
# 1048   34        No      Travel_Rarely       1326                   Sales
# 440    34       Yes  Travel_Frequently        988         Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 164                  3          3          Medical              1
# 399                  1          2    Life Sciences              1
# 636                 25          4    Life Sciences              1
# 308                  1          4    Life Sciences              1
# 1317                 5          2    Life Sciences              1
# 836                 23          1    Life Sciences              1
# 254                 20          2        Marketing              1
# 187                 14          4          Medical              1
# 1048                 3          3            Other              1
# 440                 23          3  Human Resources              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 164              224  ...                         4            80
# 399              530  ...                         3            80
# 636              881  ...                         1            80
# 308              422  ...                         4            80
# 1317            1850  ...                         3            80
# 836             1165  ...                         1            80
# 254              349  ...                         4            80
# 187              254  ...                         4            80
# 1048            1478  ...                         4            80
# 440              590  ...                         3            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 164                  1                  1                      2
# 399                  1                  4                      3
# 636                  1                 10                      3
# 308                  1                 12                      2
# 1317                 0                  6                      3
# 836                  1                 11                      3
# 254                  1                 10                      2
# 187                  0                 36                      3
# 1048                 0                 15                      2
# 440                  3                 11                      2
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 164                2               1                  1
# 399                3               4                  2
# 636                2              10                  2
# 308                3               5                  3
# 1317               2               5                  4
# 836                1              11                  8
# 254                3               3                  2
# 187                3              24                 15
# 1048               3              13                  9
# 440                3               3                  2
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 164                         0                     1
# 399                         3                     2
# 636                         7                     8
# 308                         1                     2
# 1317                        0                     2
# 836                         3                    10
# 254                         0                     2
# 187                         2                    15
# 1048                        3                    12
# 440                         0                     2
#
# [10 rows x 35 columns]

# %%
hr_data.tail(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1460                28          4        Medical              1
# 1461                28          3      Marketing              1
# 1462                24          1      Marketing              1
# 1463                 5          3        Medical              1
# 1464                 5          3          Other              1
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1460            2054  ...                         2            80
# 1461            2055  ...                         2            80
# 1462            2056  ...                         1            80
# 1463            2057  ...                         2            80
# 1464            2060  ...                         4            80
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1460                 0                  5                      3
# 1461                 1                 20                      3
# 1462                 1                 21                      2
# 1463                 0                 10                      2
# 1464                 0                  5                      2
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1460               1               5                  4
# 1461               3               3                  2
# 1462               2              20                  9
# 1463               3               9                  4
# 1464               3               4                  2
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1460                        0                     4
# 1461                        2                     0
# 1462                        9                     6
# 1463                        1                     7
# 1464                        0                     0
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [10 rows x 35 columns]

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
missing_val={}
for i in hr_data.columns:
    if hr_data[i].isnull().sum()>0:
     missing_val[i]=hr_data[i].isnull().sum()
    print(missing_val)
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}

# %%
object_columns=hr_data.select_dtypes(include="object")
num_col=hr_data.select_dtypes(exclude="object")
print("object_columns count",object_columns.shape[1])
print("number columns count",num_col.shape[1])
# Out:
# object_columns count 9
# number columns count 26

# %%
hr_data.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked        1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike         1470.0     15.209524     3.659938    11.0    12.00
# PerformanceRating         1470.0      3.153741     0.360824     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712245     1.081209     1.0     2.00
# StandardHours             1470.0     80.000000     0.000000    80.0    80.00
# StockOptionLevel          1470.0      0.793878     0.852077     0.0     0.00
# TotalWorkingYears         1470.0     11.279592     7.780782     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799320     1.289271     0.0     2.00
# WorkLifeBalance           1470.0      2.761224     0.706476     1.0     2.00
# YearsAtCompany            1470.0      7.008163     6.126525     0.0     3.00
# YearsInCurrentRole        1470.0      4.229252     3.623137     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.187755     3.222430     0.0     0.00
# YearsWithCurrManager      1470.0      4.123129     3.568136     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %%
object_columns.describe()
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
print(hr_data["Attrition"].value_counts(),"\n")
sns.countplot(hr_data["Attrition"])
plt.title("Target class values distribution");
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
hr_data.groupby("Attrition")[["Age","DailyRate","DistanceFromHome","HourlyRate","MonthlyIncome","MonthlyRate","PercentSalaryHike","TrainingTimesLastYear","TotalWorkingYears","YearsWithCurrManager"]].mean()
# Out:
#                  Age   DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  \
# Attrition
# No         37.561233  812.504461          8.915653   65.952149    6832.739659
# Yes        33.607595  750.362869         10.632911   65.573840    4787.092827
#
#             MonthlyRate  PercentSalaryHike  TrainingTimesLastYear  \
# Attrition
# No         14265.779400          15.231144               2.832928
# Yes        14559.308017          15.097046               2.624473
#
#            TotalWorkingYears  YearsWithCurrManager
# Attrition
# No                 11.862936              4.367397
# Yes                 8.244726              2.852321

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="BusinessTravel", y="Age", data=hr_data,hue="Attrition")
plt.title("Business Travel wise attrition")
# Out:
# Text(0.5, 1.0, 'Business Travel wise attrition')

# %%
print(hr_data["Department"].value_counts())
hr_data.groupby(["Department","Attrition"])["Attrition"].count().plot(kind="barh")
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# <AxesSubplot:ylabel='Department,Attrition'>

# %%
hr_data.groupby(["Attrition","EducationField"])["Attrition"].count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Attrition,EducationField'>

# %%
distance=pd.cut(hr_data["DistanceFromHome"],bins=5)
for_analysis=pd.concat([hr_data["Attrition"],distance],axis=1,join="inner")
plt.figure(figsize=(15,5))
for_analysis.groupby(["Attrition","DistanceFromHome"])["Attrition"].count().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Attrition,DistanceFromHome'>

# %%
plt.figure(figsize=(15,5))
hr_data.groupby(["Attrition","Education"])["Attrition"].count().plot(kind="barh")
plt.title("Educational_place wise attrition")
"""Education<br>
1 'Below College'
2 'College'
3 'Bachelor'
4 'Master'
5 'Doctor'"""
# Out:
# "Education<br>\n1 'Below College'\n2 'College'\n3 'Bachelor'\n4 'Master'\n5 'Doctor'"

# %%
plt.figure(figsize=(15,5))
hr_data.groupby(["Attrition","EnvironmentSatisfaction"])["EnvironmentSatisfaction"].count().plot(kind="barh")
plt.title("EnvironmentSatisfaction wise attrition");
"""EnvironmentSatisfaction
1 'Low'
2 'Medium'
3 'High'
4 'Very High'"""
# Out:
# "EnvironmentSatisfaction\n1 'Low'\n2 'Medium'\n3 'High'\n4 'Very High'"

# %%
plt.figure(figsize=(15,5))
hr_data.groupby(["Attrition","Gender"])["Gender"].count().plot(kind="barh")
plt.title("Gender wise attrition");

# %%
plt.figure(figsize=(15,5))
hr_data.groupby(["Attrition","PerformanceRating"])["PerformanceRating"].count().plot(kind="barh")
plt.title("Performance Rating wise attrition");

# %%
hr_data1=hr_data.copy()

# %%
num_col_boxplot=hr_data1[["DailyRate","DistanceFromHome","HourlyRate","MonthlyIncome","MonthlyRate"]]
num_col_boxplot.boxplot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
hr_data1.boxplot("Age")
# Out:
# <AxesSubplot:>

# %%
hr_data1.boxplot("YearsWithCurrManager")
# Out:
# <AxesSubplot:>

# %%
hr_data1.boxplot("YearsInCurrentRole")
# Out:
# <AxesSubplot:>

# %%
hr_data1["DistanceFromHome"]=np.cbrt(hr_data1["DistanceFromHome"])
hr_data1["MonthlyIncome"]=np.log(hr_data1["MonthlyIncome"])

# %%
hr_data1[["Age","DailyRate","DistanceFromHome","HourlyRate","MonthlyIncome","MonthlyRate"]].skew()
# Out:
# Age                 0.413286
# DailyRate          -0.003519
# DistanceFromHome   -0.101978
# HourlyRate         -0.032311
# MonthlyIncome       0.286192
# MonthlyRate         0.018578
# dtype: float64

# %% [markdown]
# # Label Encoding

# %%
object_columns.sample(10)
# Out:
#      Attrition BusinessTravel              Department    EducationField  \
# 1242        No  Travel_Rarely                   Sales           Medical
# 483         No  Travel_Rarely  Research & Development             Other
# 97          No     Non-Travel                   Sales           Medical
# 506         No  Travel_Rarely  Research & Development             Other
# 937         No  Travel_Rarely  Research & Development           Medical
# 1393        No  Travel_Rarely                   Sales         Marketing
# 231         No  Travel_Rarely  Research & Development  Technical Degree
# 1312       Yes  Travel_Rarely         Human Resources   Human Resources
# 574         No  Travel_Rarely  Research & Development     Life Sciences
# 161         No     Non-Travel  Research & Development           Medical
#
#       Gender                 JobRole MaritalStatus Over18 OverTime
# 1242    Male                 Manager        Single      Y       No
# 483     Male   Laboratory Technician        Single      Y       No
# 97      Male         Sales Executive       Married      Y       No
# 506     Male  Manufacturing Director       Married      Y       No
# 937   Female                 Manager      Divorced      Y      Yes
# 1393    Male         Sales Executive        Single      Y       No
# 231     Male                 Manager       Married      Y       No
# 1312    Male         Human Resources       Married      Y       No
# 574   Female      Research Scientist        Single      Y       No
# 161     Male      Research Scientist      Divorced      Y       No

# %%
hr_data1["Attrition"]=hr_data1["Attrition"].replace({"Yes":1,"No":0})
hr_data1["Gender"]=hr_data1["Gender"].replace({"Female":0,"Male":1})
hr_data1["Department"]=hr_data1["Department"].replace({"Human Resources":0,"Research & Development":1,"Sales":2})
hr_data1["MaritalStatus"]=hr_data1["MaritalStatus"].replace({"Divorced":0,"Married":1,"Single":2})
hr_data1["OverTime"]=hr_data1["OverTime"].replace({"Yes":0,"No":1})
hr_data1["BusinessTravel"]=hr_data1["BusinessTravel"].replace({"Non-Travel":0,"Travel_Frequently":1,"Travel_Rarely":2})

# %%
edu={'Life Sciences':2,
    'Other':1,
    'Medical':4,
    'Marketing':3,
    'Technical Degree':5,
    'Human Resources':0}
jon_role={'Sales Executive':7,
         'Research Scientist':5,
         'Laboratory Technician':2,
         'Manufacturing Director':3,
         'Healthcare Representative':1,
         'Manager':4,
         'Sales Representative':8,
         'Research Director':6,
         'Human Resources':0}

# %%
hr_data1["EducationField"]=hr_data1["EducationField"].replace(edu)
hr_data1["JobRole"]=hr_data1["JobRole"].replace(jon_role)

# %%
hr_data1.sample(5)
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 841    24          0               2        477           1          1.423498
# 453    26          1               1        426           0          1.369987
# 133    41          0               2        802           2          1.276518
# 920    34          0               1        135           1          1.387023
# 1455   40          0               2       1322           1          1.080060
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 841           3               4              1            1173  ...
# 453           4               2              1             608  ...
# 133           1               2              1             176  ...
# 920           3               4              1            1285  ...
# 1455          4               2              1            2048  ...
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 841                          4             80                 0
# 453                          2             80                 1
# 133                          3             80                 1
# 920                          3             80                 2
# 1455                         4             80                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 841                   6                      2                3
# 453                   8                      2                2
# 133                  12                      2                3
# 920                  15                      2                4
# 1455                  8                      2                3
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 841                4                   3                        1
# 453                7                   7                        1
# 133                9                   7                        0
# 920               11                   8                        5
# 1455               2                   2                        2
#
#       YearsWithCurrManager
# 841                      2
# 453                      0
# 133                      7
# 920                     10
# 1455                     2
#
# [5 rows x 35 columns]

# %%
hr_data1.drop(columns=["Over18","EmployeeCount","EmployeeNumber","StandardHours"],axis=1,inplace=True)

# %% [markdown]
# # HeatMap

# %%
plt.figure(figsize=(20,15))
sns.heatmap(hr_data1.corr(),annot=True)
plt.title("Correlation Plot")
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %%
hr_data1.drop(columns=["YearsAtCompany","JobLevel","JobRole","TotalWorkingYears","PercentSalaryHike"],axis=1,inplace=True)
plt.figure(figsize=(20,15))
sns.heatmap(hr_data1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X=hr_data1.drop("Attrition",axis=1)
y=hr_data1["Attrition"]

# %%
from imblearn.combine import SMOTETomek
smote=SMOTETomek(random_state=40)
res_X,res_y=smote.fit_resample(X,y)

# %% [markdown]
# # Modeling

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
for i in range(50,500,75):
    RF=RandomForestClassifier()
    X_train,X_test,y_train,y_test=train_test_split(res_X,res_y,test_size=0.2,random_state=i)
    RF.fit(X_train,y_train)
    print("training score:", RF.score(X_train,y_train),"Random_state",i)
    pred=RF.predict(X_test)
    print("Test score:",RF.score(X_test,y_test),"Random_state",i)
    print("Accuracy:",accuracy_score(pred,y_test))
    print("Roc_auc_score:",roc_auc_score(pred,y_test))
    print("confusion_matrix","\n",confusion_matrix(pred,y_test))
    print("classification_report","\n",classification_report(pred,y_test))
# Out:
# training score: 1.0 Random_state 50
# Test score: 0.9024943310657596 Random_state 50
# Accuracy: 0.9024943310657596
# Roc_auc_score: 0.9023818338886833
# confusion_matrix
#  [[194  25]
#  [ 18 204]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90       219
#            1       0.89      0.92      0.90       222
#
#     accuracy                           0.90       441
#    macro avg       0.90      0.90      0.90       441
# weighted avg       0.90      0.90      0.90       441
#
# training score: 1.0 Random_state 125
# Test score: 0.9206349206349206 Random_state 125
# Accuracy: 0.9206349206349206
# Roc_auc_score: 0.9216450216450217
# confusion_matrix
#  [[208  23]
#  [ 12 198]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92       231
#            1       0.90      0.94      0.92       210
#
#     accuracy                           0.92       441
#    macro avg       0.92      0.92      0.92       441
# weighted avg       0.92      0.92      0.92       441
#
# training score: 1.0 Random_state 200
# Test score: 0.9115646258503401 Random_state 200
# Accuracy: 0.9115646258503401
# Roc_auc_score: 0.9131712280410316
# confusion_matrix
#  [[217  25]
#  [ 14 185]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       242
#            1       0.88      0.93      0.90       199
#
#     accuracy                           0.91       441
#    macro avg       0.91      0.91      0.91       441
# weighted avg       0.91      0.91      0.91       441
#
# training score: 1.0 Random_state 275
# Test score: 0.9229024943310657 Random_state 275
# Accuracy: 0.9229024943310657
# Roc_auc_score: 0.9267498643516008
# confusion_matrix
#  [[221  26]
#  [  8 186]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       247
#            1       0.88      0.96      0.92       194
#
#     accuracy                           0.92       441
#    macro avg       0.92      0.93      0.92       441
# weighted avg       0.93      0.92      0.92       441
#
# training score: 1.0 Random_state 350
# Test score: 0.909297052154195 Random_state 350
# Accuracy: 0.909297052154195
# Roc_auc_score: 0.9104224134381819
# confusion_matrix
#  [[198  29]
#  [ 11 203]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       227
#            1       0.88      0.95      0.91       214
#
#     accuracy                           0.91       441
#    macro avg       0.91      0.91      0.91       441
# weighted avg       0.91      0.91      0.91       441
#
# training score: 1.0 Random_state 425
# Test score: 0.9024943310657596 Random_state 425
# Accuracy: 0.9024943310657596
# Roc_auc_score: 0.9028213166144201
# confusion_matrix
#  [[208  24]
#  [ 19 190]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       232
#            1       0.89      0.91      0.90       209
#
#     accuracy                           0.90       441
#    macro avg       0.90      0.90      0.90       441
# weighted avg       0.90      0.90      0.90       441

# %% [markdown]
# # GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
models=[LogisticRegression(),RandomForestClassifier(),AdaBoostClassifier(),DecisionTreeClassifier(),GaussianNB(),SVC(),KNeighborsClassifier()]
for model in models:
    X_train1,X_test1,y_train1,y_test1=train_test_split(res_X,res_y,test_size=0.2, random_state=275)
    model.fit(X_train1,y_train)
    print("training score:",model.score(X_train1,y_train1),"Model",model)
    pred=model.predict(X_test1)
    print("Test score:",RF.score(X_test1,y_test1))
    print("Accuracy:",accuracy_score(pred,y_test1))
    print("Roc_auc_score:",roc_auc_score(pred,y_test1))
    print("confusion_matrix","\n",confusion_matrix(pred,y_test1))
    print("classification_report","\n",classification_report(pred,y_test1))
# Out:
# training score: 0.4684838160136286 Model LogisticRegression()
# Test score: 0.9886621315192744
# Accuracy: 0.48072562358276644
# Roc_auc_score: 0.48293172690763053
# confusion_matrix
#  [[ 96  96]
#  [133 116]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.42      0.50      0.46       192
#            1       0.55      0.47      0.50       249
#
#     accuracy                           0.48       441
#    macro avg       0.48      0.48      0.48       441
# weighted avg       0.49      0.48      0.48       441
#
# training score: 0.5184554230550823 Model RandomForestClassifier()
# Test score: 0.9886621315192744
# Accuracy: 0.5192743764172335
# Roc_auc_score: 0.5183982683982684
# confusion_matrix
#  [[124 107]
#  [105 105]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54       231
#            1       0.50      0.50      0.50       210
#
#     accuracy                           0.52       441
#    macro avg       0.52      0.52      0.52       441
# weighted avg       0.52      0.52      0.52       441
#
# training score: 0.5122089721749006 Model AdaBoostClassifier()
# Test score: 0.9886621315192744
# Accuracy: 0.4897959183673469
# Roc_auc_score: 0.48966432185610265
# confusion_matrix
#  [[113 109]
#  [116 103]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.49      0.51      0.50       222
#            1       0.49      0.47      0.48       219
#
#     accuracy                           0.49       441
#    macro avg       0.49      0.49      0.49       441
# weighted avg       0.49      0.49      0.49       441
#
# training score: 0.5184554230550823 Model DecisionTreeClassifier()
# Test score: 0.9886621315192744
# Accuracy: 0.5396825396825397
# Roc_auc_score: 0.5428903112449799
# confusion_matrix
#  [[109  83]
#  [120 129]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.48      0.57      0.52       192
#            1       0.61      0.52      0.56       249
#
#     accuracy                           0.54       441
#    macro avg       0.54      0.54      0.54       441
# weighted avg       0.55      0.54      0.54       441
#
# training score: 0.6717773992049971 Model GaussianNB()
# Test score: 0.9886621315192744
# Accuracy: 0.6417233560090703
# Roc_auc_score: 0.6464043957880662
# confusion_matrix
#  [[132  61]
#  [ 97 151]]
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.58      0.68      0.63       193
#            1       0.71      0.61      0.66       248
#
#     accuracy                           0.64       441
#    macro avg       0.64      0.65      0.64       441
# weighted avg       0.65      0.64      0.64       441
#
# training score: 0.5048268029528676 Model SVC()
# Test score: 0.9886621315192744
# Accuracy: 0.48072562358276644
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_20720/3067150929.py in <module>
#      12     print("Test score:",RF.score(X_test1,y_test1))
#      13     print("Accuracy:",accuracy_score(pred,y_test1))
# ---> 14     print("Roc_auc_score:",roc_auc_score(pred,y_test1))
#      15     print("confusion_matrix","\n",confusion_matrix(pred,y_test1))
#      16     print("classification_report","\n",classification_report(pred,y_test1))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     569         labels = np.unique(y_true)
#     570         y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 571         return _average_binary_score(
#     572             partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     573             y_true,
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      73
#      74     if y_type == "binary":
# ---> 75         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      76
#      77     check_consistent_length(y_true, y_score, sample_weight)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     337     """Binary roc auc score."""
#     338     if len(np.unique(y_true)) != 2:
# --> 339         raise ValueError(
#     340             "Only one class present in y_true. ROC AUC score "
#     341             "is not defined in that case."
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
para={"n_estimators":[100,200,300,400],
     "max_depth":[2,3,4],
     "max_features":["auto","sqrt","log2"]}
grid_RF=RandomForestClassifier()
grid_RF=GridSearchCV(grid_RF,para,scoring="f1",cv=10,n_jobs=-1,verbose=2)
grid_RF.fit(X_train1,y_train1)
print(grid_RF.best_score_)
print(grid_RF.best_params_)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# 0.8747513866017202
# {'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 100}

# %% [markdown]
# #cross validation

# %%
grid_RF= RandomForestClassifier(max_depth=4,max_features='log2',n_estimators=400)
for i in range(2,10):
    cross_score=cross_val_score(grid_RF,res_X,res_y,scoring="f1",cv=i)
    print("CV",i,"mean",cross_score.mean(),"std",cross_score.std())
# Out:
# CV 2 mean 0.8578313338244047 std 0.041545335810501904
# CV 3 mean 0.8591743526565222 std 0.06838280077322317
# CV 4 mean 0.8599808746454476 std 0.08479199983566903
# CV 5 mean 0.855940360939767 std 0.10156070791149416
# CV 6 mean 0.8602799350884814 std 0.09936459807517649
# CV 7 mean 0.86343076978805 std 0.08396588465176424
# CV 8 mean 0.8611940966121969 std 0.09076606898612588
# CV 9 mean 0.8639931259911614 std 0.09284112883623218

# %% [markdown]
# # Model Saving

# %%
import pickle 
grid_RF.fit(res_X,res_y)
filename="HR_Attrition_Analytic.pkl"
with open(filename,"wb") as f:
    pickle.dump(grid_RF,f)
