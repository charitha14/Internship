# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: idna in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: outcome in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hucon solutions pvt\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %% [markdown]
# # Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_1688/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.amazon.in/"
driver.get(url)

# %%
user_input = input('Enter the product to search : ')
# Out:
# Enter the product to search : Guitar

# %%
search = driver.find_element(By.ID,'twotabsearchtextbox')
search
search.send_keys(user_input)
search_btn = driver.find_element(By.XPATH,"//div[@class='nav-search-submit nav-sprite']/span/input")

search_btn.click()

# %% [markdown]
# # In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
urls = []         
for i in range(0,3):     
    page_url = driver.find_elements(By.XPATH,"//a[@class='a-link-normal a-text-normal']")
    for i in page_url:
        urls.append(i.get_attribute("href"))
        next_btn = driver.find_elements(By.XPATH,"//li[@class='a-last']/a")
        time.sleep(3)

# %%
len(urls)
# Out:
# 6

# %%
brand_name = []
product_name = []
ratings = []
num_ratings = []
prices = []
exchange = []
exp_delivery = []
availability = []
other_details = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    # brand name
    try:
        brand = driver.find_element(By.XPATH,"//a[@id='bylineInfo']")
        brand_name.append(brand.text)
    except NoSuchElementException:
        brand_name.append('-')
    
    
    #product name
    try:
        product = driver.find_element(By.XPATH,"//span[@id='productTitle']")
        product_name.append(product.text)
    except NoSuchElementException:
        product_name.append('-')
        
        

     # ratings
    try:
        rating = driver.find_element(By.XPATH,"//span[@class='a-size-base a-nowrap']/span")
        ratings.append(rating.text)
    except NoSuchElementException:
        ratings.append('-')
        
 
    # no of ratings
    try:
        num_rating = driver.find_element(By.XPATH,"//span[@id='acrCustomerReviewText']")
        num_ratings.append(num_rating.text)
    except NoSuchElementException:
        num_ratings.append('-')
        

    #price of the product
    try:
        price = driver.find_element(By.XPATH,"//td[@class='a-span12']")
        prices.append(price.text)
    except NoSuchElementException:
        prices.append('-')
        
        
    #return/exchange
    try:
        exch = driver.find_element(By.XPATH,"//span[@class='a-declarative']/div/a")
        exchange.append(exch.text)
    except NoSuchElementException:
        exchange.append('-')
        

    # expected delivery
    try:
        delivery = driver.find_element(By.XPATH,"//div[@class='a-section a-spacing-mini']/b")
        exp_delivery.append(delivery.text)
    except NoSuchElementException:
        exp_delivery.append('-')
        

    # availability information
    try:
        avail = driver.find_element(By.XPATH,"//span[@class='a-size-medium a-color-success']")
        availability.append(avail.text)
    except NoSuchElementException:
        availability.append('-')
        
    #other details
    try:
        oth_det = driver.find_element(By.XPATH,"//ul[@class='a-unordered-list a-vertical a-spacing-mini']")
        other_details.append(oth_det.text)
    except NoSuchElementException:
        other_details.append('-')

# %%
print(len(brand_name),
len(product_name),
len(ratings),
len(num_ratings),
len(prices),
len(exchange),
len(exp_delivery),
len(availability),
len(other_details))
# Out:
# 6 6 6 6 6 6 6 6 6

# %%
guitar = pd.DataFrame({})
guitar['Brand Name'] = brand_name
guitar['Name of the Product'] = product_name
guitar['Rating'] = ratings
guitar['No. of Ratings'] = num_ratings
guitar['Price'] = prices
guitar['Return/Exchange'] = exchange
guitar['Expected Delivery'] = exp_delivery
guitar['Availability'] = availability
guitar['Other Details'] = other_details
guitar['Product URL'] = urls
guitar
# Out:
#                 Brand Name                                Name of the Product  \
# 0  Visit the Kadence Store  Kadence Guitar Acoustica Series, 41” Jumbo Siz...
# 1  Visit the Kadence Store  Kadence Guitar Acoustica Series, Electric Acou...
# 2  Visit the Kadence Store  Kadence Guitar Acoustica Series, 41” Jumbo Siz...
# 3  Visit the Kadence Store  Kadence Guitar Acoustica Series, Electric Acou...
# 4  Visit the Kadence Store  Kadence Guitar Acoustica Series, 41” Jumbo Siz...
# 5  Visit the Kadence Store  Kadence Guitar Acoustica Series, Electric Acou...
#
#          Rating No. of Ratings      Price     Return/Exchange  \
# 0  4.2 out of 5    208 ratings          -  7 Days Replacement
# 1  3.9 out of 5  1,180 ratings  ₹6,499.00  7 Days Replacement
# 2  4.2 out of 5    208 ratings          -  7 Days Replacement
# 3  3.9 out of 5  1,180 ratings  ₹6,499.00  7 Days Replacement
# 4  4.2 out of 5    208 ratings          -  7 Days Replacement
# 5  3.9 out of 5  1,180 ratings  ₹6,499.00  7 Days Replacement
#
#   Expected Delivery Availability  \
# 0                 -    In stock.
# 1                 -
# 2                 -    In stock.
# 3                 -
# 4                 -    In stock.
# 5                 -
#
#                                        Other Details  \
# 0  CLASSIC DESIGN ---Elegant inlay provides a cla...
# 1  *ACOUSTIC-ELECTRIC GUITAR: Kadence ash wood gu...
# 2  CLASSIC DESIGN ---Elegant inlay provides a cla...
# 3  *ACOUSTIC-ELECTRIC GUITAR: Kadence ash wood gu...
# 4  CLASSIC DESIGN ---Elegant inlay provides a cla...
# 5  *ACOUSTIC-ELECTRIC GUITAR: Kadence ash wood gu...
#
#                                          Product URL
# 0  https://aax-eu.amazon.in/x/c/Q6XqovD4TtdueW97N...
# 1  https://aax-eu.amazon.in/x/c/Q-5hbgURmWVwN5rSo...
# 2  https://aax-eu.amazon.in/x/c/Q6XqovD4TtdueW97N...
# 3  https://aax-eu.amazon.in/x/c/Q-5hbgURmWVwN5rSo...
# 4  https://aax-eu.amazon.in/x/c/Q6XqovD4TtdueW97N...
# 5  https://aax-eu.amazon.in/x/c/Q-5hbgURmWVwN5rSo...

# %%
guitar.to_csv("Guitar.csv")

# %%
driver.close()

# %% [markdown]
# # Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_11864/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
   
# Getting the webpage of mentioned url 
url = "https://images.google.com/"
#Creating empty list 
urls = []    #empty list
data = []    #empty list
search_item = ["fruits", "cars", "Machine Learning", "Guitar","Cakes"]
for item in search_item:
    driver.get(url)  
    time.sleep(5)
    
    # Finding webelement for search_bar
    search_bar = driver.find_element(By.TAG_NAME,"input") 
    
    # Sending keys to get the keyword for search bar
    search_bar.send_keys(str(item))
    
    # Clicking on search button
    search_button =driver.find_element(By.XPATH,"//button[@class='Tg7LZd']").click()
    
    # Scrolling down the webpage to get some more images
    for _ in range(10):
        driver.execute_script("window.scrollBy(0,10)")
        
        imgs = driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:10]:
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response = requests.get(urls[i])

    file = open(r"C:\Users\HUCON SOLUTIONS PVT\OneDrive\Desktop\Flip Robo Technologies\Images"+str(i)+".jpg", "wb")

    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %%
driver.close()

# %% [markdown]
# # Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_11864/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
login_x_btn = driver.find_element(By.XPATH,"//div[@class='_2QfC02']//button").click()

# %%
search_bar = driver.find_element(By.XPATH,"//input[@class='_3704LK']")

# %%
search_bar.send_keys("pixel 4A")

# %%
search_btn = driver.find_element(By.XPATH,"//button[@class='L0Z3Pu']")

# %%
search_btn.click()

# %%
page1_url = []
urls = driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
for url in urls:
    page1_url.append(url.get_attribute('href'))

# %%
len(page1_url)
# Out:
# 24

# %%
Smartphones = ({})
Smartphones['Brand'] = []
Smartphones['Phone name'] = []
Smartphones['Colour'] = []
Smartphones['RAM'] = []
Smartphones['Storage(ROM)'] = []
Smartphones['Primary Camera'] = []
Smartphones['Secondary Camera'] = []
Smartphones['Display Size'] = []
Smartphones['Display Resolution'] = []
Smartphones['Processor Cores'] = []
Smartphones['Battery Capacity'] = []
Smartphones['Price'] = []
Smartphones['URL'] = []

# %%
for url in page1_url:
    driver.get(url)
    print("Scraping URL = ",url)
    Smartphones['URL'].append(url)
    time.sleep(2)
    
    
    
    try:
        read_more = driver.find_element(By.XPATH,"//button[@class='_2KpZ6l _1FH0tX']")
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
    
    #brand name of smartphone
    try:
        brand_tags = driver.find_element(By.XPATH,"//span[@class='B_NuCI']")
        Smartphones['Brand'].append(brand_tags.text.split()[0])
    except NoSuchElementException:
        Smartphones['Brand'].append('-')
    
    
    # name of smartphones
    try:
        name_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][1]/table/tbody/tr[3]/td[2]/ul/li")
        Smartphones['Phone name'].append(name_tags.text)
    except NoSuchElementException:
        Smartphones['Phone name'].append('-')
        
    #colour of smartphone
    try:
        color_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li")
        Smartphones['Colour'].append(color_tags.text)
    except NoSuchElementException:
        Smartphones['Colour'].append('-')
        
    #RAM data of smartphone
    try:
        ram_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][4]/table[1]/tbody/tr[2]/td[2]/ul/li")
        Smartphones['RAM'].append(ram_tags.text)
    except NoSuchElementException:
        Smartphones['RAM'].append('-')
        
    #ROM data of smartphones
    try:
        rom = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][4]/table[1]/tbody/tr[1]/td[2]/ul/li")
        Smartphones['Storage(ROM)'].append(rom.text)
    except NoSuchElementException:
        Smartphones['Storage(ROM)'].append('-')
        
    #Primary camera data of smartphone
    try:
        pri =driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[2]/td[2]/ul/li")
        Smartphones['Primary Camera'].append(pri.text)
    except NoSuchElementException:
        Smartphones['Primary Camera'].append('-')
        
    #secondary camera data of smartphone
    try:
        sec = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[6]/td[1]")
        if sec != 'Secondary Camera' :
            if driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[5]/td[1]").text == "Secondary Camera":
                sec_cam =driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[5]/td[2]/ul/li")
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][5]/table[1]/tbody/tr[6]/td[2]/ul/li")
        Smartphones['Secondary Camera'].append(sec_cam.text)
    except NoSuchElementException:
        Smartphones['Secondary Camera'].append('-')
        
    
    #display size data of smartphone
    try:
        disp = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][2]/div")
        if disp.text != 'Display Features' : raise NoSuchElementException
        disp_size = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][2]/table[1]/tbody/tr[1]/td[2]/ul/li")
        Smartphones['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        Smartphones['Display Size'].append('-')
        
    
    #display resolution of smartphone
    try:
        disp = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][2]/div")
        if disp.text != 'Display Features' : raise NoSuchElementException
        disp_reso = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][2]/table[1]/tbody/tr[2]/td[2]/ul/li")
        Smartphones['Display Resolution'].append(disp_reso.text)
    except NoSuchElementException:
        Smartphones['Display Resolution'].append('-')
        
        

        
       
    # processor core of smartphone
    try:
        core = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][3]/table[1]/tbody/tr[3]/td[1]")
        if core.text != 'Processor Core' :
            core = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][3]/table[1]/tbody/tr[2]/td[1]")
            if core.text != 'Processor Core' :
                raise NoSuchElementException
            else :
                cores = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][3]/table[1]/tbody/tr[2]/td[2]/ul/li")
        else :
            cores = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][3]/table[1]/tbody/tr[3]/td[2]/ul/li")
        Smartphones['Processor Cores'].append(disp_reso.text)
    except NoSuchElementException:
        Smartphones['Processor Cores'].append('-')
        
        
        
    # battery capacity of smartphone
    try:
        if driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][10]/div").text != "Battery & Power Features" :
            if driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][9]/div").text == "Battery & Power Features" :
                bat_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][9]/table/tbody/tr/td[1]")
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][9]/table/tbody/tr/td[2]/ul/li")
            elif driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][8]/div").text == "Battery & Power Features" :
                bat_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][8]/table/tbody/tr/td[1]")
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][8]/table/tbody/tr/td[2]/ul/li")
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][10]/table/tbody/tr/td[1]")
            if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element(By.XPATH,"//div[@class='_3k-BhJ'][10]/table/tbody/tr/td[2]/ul/li")
        Smartphones['Battery Capacity'].append(bat_capa.text)
    except NoSuchElementException:
        Smartphones['Battery Capacity'].append('-')
    
    
    
    
    # price of smartphone
    try:
        price_tags = driver.find_element(By.XPATH,"//div[@class='_30jeq3 _16Jk6d']")
        Smartphones['Price'].append(price_tags.text)
    except NoSuchElementException:
          Smartphones['Price'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBFUSBNAZGY7HQU.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10-prime-phantom-black-64-gb/p/itm749a50b87eba4?pid=MOBG6RGHHA2DGZZY&lid=LSTMOBG6RGHHA2DGZZYBKFIKP&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBG6RGHHA2DGZZY.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP57SXRTY&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHVHNBBBBP5.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVKYHCVG7W&lid=LSTMOBGDRHVKYHCVG7WU0WEW8&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHVKYHCVG7W.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHVZN29ZJF4.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHVMW2UDXZY.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-10a-slate-grey-64-gb/p/itm755830dd54ae1?pid=MOBGDRGV2UAGZYZG&lid=LSTMOBGDRGV2UAGZYZGXPNXJ1&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRGV2UAGZYZG.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-note-10-pro-max-dark-nebula-128-gb/p/itm32dc939d5a40f?pid=MOBGF8VJY8ZFKPMK&lid=LSTMOBGF8VJY8ZFKPMKQSKZBG&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGF8VJY8ZFKPMK.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHVXFVCGS23.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-note-11-space-black-64-gb/p/itm2a388ca843b21?pid=MOBGBHCKZNYYG5QA&lid=LSTMOBGBHCKZNYYG5QAVWGPND&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGBHCKZNYYG5QA.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7H8GFGZPYUFH&lid=LSTMOBG7H8GFGZPYUFHNXKCJA&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBG7H8GFGZPYUFH.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-note-10-pro-max-vintage-bronze-128-gb/p/itm02a7f06662d36?pid=MOBGB725DAFRFAVC&lid=LSTMOBGB725DAFRFAVCGJNXDL&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGB725DAFRFAVC.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-light-sea-green-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HQJZKSX3K&lid=LSTMOBGDC6HQJZKSX3KUVADVY&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDC6HQJZKSX3K.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDC6HFGCW5PGF.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-heart-ocean-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HN5VTU6RR&lid=LSTMOBGDC6HN5VTU6RRUSMZV8&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDC6HN5VTU6RR.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7DGGNP5N2RXH&lid=LSTMOBG7DGGNP5N2RXHOLY5IC&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBG7DGGNP5N2RXH.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/google-pixel-6a-chalk-128-gb/p/itme5ae89135d44e?pid=MOBGFWEZ5SKU84Z8&lid=LSTMOBGFWEZ5SKU84Z8FXPB45&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGFWEZ5SKU84Z8.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-polar-black-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HZHYVX96A&lid=LSTMOBGDC6HZHYVX96AHNLOZE&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDC6HZHYVX96A.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJMHFQJFCX3&lid=LSTMOBG7CJMHFQJFCX3TCC7KY&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBG7CJMHFQJFCX3.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBG7CJZZRCJ3XHG&lid=LSTMOBG7CJZZRCJ3XHGG7UNWC&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBG7CJZZRCJ3XHG.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/redmi-9a-sport-metallic-blue-32-gb/p/itm53bc6ebfe147b?pid=MOBG7GY6GGZ8XZGM&lid=LSTMOBG7GY6GGZ8XZGMIEH6AV&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBG7GY6GGZ8XZGM.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/google-pixel-6a-charcoal-128-gb/p/itme5ae89135d44e?pid=MOBGFKX5YUXD74Z3&lid=LSTMOBGFKX5YUXD74Z3MXA2OB&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGFKX5YUXD74Z3.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm6fabe8894256b?pid=MOBGDRHV86NZHMDM&lid=LSTMOBGDRHV86NZHMDMR0BLSS&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHV86NZHMDM.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm6fabe8894256b?pid=MOBGDRHVHYFKQP8K&lid=LSTMOBGDRHVHYFKQP8KYHDDNN&marketplace=FLIPKART&q=pixel+4A&store=search.flipkart.com%2Ftyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=855a6e45-f855-403d-a281-697801303e1e.MOBGDRHVHYFKQP8K.SEARCH&ppt=hp&ppn=homepage&ssid=ieslkb65340000001659362558542&qH=9b26a23b2cff510d

# %%
print(len(Smartphones['Brand']),len(Smartphones['Phone name']), len(Smartphones['Colour']),len(Smartphones['RAM']),len(Smartphones['Storage(ROM)']),len(Smartphones['Primary Camera']),len(Smartphones['Secondary Camera']), len(Smartphones['Display Size']), len(Smartphones['Display Resolution']), len(Smartphones['Processor Cores']), len(Smartphones['Battery Capacity']), len(Smartphones['Price']), len(Smartphones['URL']))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24 24 24

# %%
df = pd.DataFrame.from_dict(Smartphones)
df
# Out:
#       Brand       Phone name           Colour   RAM Storage(ROM)  \
# 0    Google         Pixel 4a       Just Black  6 GB       128 GB
# 1     REDMI         10 Prime    Phantom Black  4 GB        64 GB
# 2      vivo           T1 44W       Starry Sky  4 GB       128 GB
# 3      vivo           T1 44W         Ice Dawn  4 GB       128 GB
# 4      vivo           T1 44W  Midnight Galaxy  4 GB       128 GB
# 5      vivo           T1 44W       Starry Sky  6 GB       128 GB
# 6     REDMI        REDMI 10A       Slate grey  4 GB        64 GB
# 7     REDMI  Note 10 Pro Max      Dark Nebula  6 GB       128 GB
# 8      vivo           T1 44W  Midnight Galaxy  6 GB       128 GB
# 9     Redmi    Redmi Note 11      Space Black  6 GB        64 GB
# 10    Redmi   Redmi 9A Sport    Metallic Blue  3 GB        32 GB
# 11    REDMI  Note 10 Pro Max   Vintage Bronze  6 GB       128 GB
# 12  Infinix          Smart 6  Light Sea Green  2 GB        64 GB
# 13  Infinix          Smart 6    Starry Purple  2 GB        64 GB
# 14  Infinix          Smart 6   Heart Of Ocean  2 GB        64 GB
# 15    Redmi   Redmi 9A Sport     Carbon Black  2 GB        32 GB
# 16   Google         Pixel 6a            Chalk  6 GB       128 GB
# 17  Infinix          Smart 6      Polar Black  2 GB        64 GB
# 18    Redmi   Redmi 9A Sport     Carbon Black  3 GB        32 GB
# 19    Redmi   Redmi 9A Sport      Coral Green  3 GB        32 GB
# 20    Redmi   Redmi 9A Sport    Metallic Blue  2 GB        32 GB
# 21   Google         Pixel 6a         Charcoal  6 GB       128 GB
# 22     vivo           T1 44W         Ice Dawn  8 GB       128 GB
# 23     vivo           T1 44W       Starry Sky  8 GB       128 GB
#
#             Primary Camera   Secondary Camera          Display Size  \
# 0       12.2MP Rear Camera   8MP Front Camera  14.76 cm (5.81 inch)
# 1   50MP + 8MP + 2MP + 2MP   8MP Front Camera   16.51 cm (6.5 inch)
# 2         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 3         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 4         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 5         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 6         13MP Rear Camera                  -  16.59 cm (6.53 inch)
# 7        108MP Rear Camera  16MP Front Camera  16.94 cm (6.67 inch)
# 8         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 9           Primary Camera                  -  16.33 cm (6.43 inch)
# 10        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 11       108MP Rear Camera  16MP Front Camera  16.94 cm (6.67 inch)
# 12       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 13       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 14       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 15        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 16           12.2MP + 12MP   8MP Front Camera   15.6 cm (6.14 inch)
# 17       8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 18        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 19        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 20        13MP Rear Camera   5MP Front Camera  16.59 cm (6.53 inch)
# 21           12.2MP + 12MP   8MP Front Camera   15.6 cm (6.14 inch)
# 22        50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 23        50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
#
#     Display Resolution     Processor Cores Battery Capacity    Price  \
# 0   2340 x 1080 Pixels  2340 x 1080 Pixels         3140 mAh  ₹31,999
# 1   2400 x 1080$$Pixel  2400 x 1080$$Pixel         6000 mAh  ₹11,498
# 2    2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹14,499
# 3    2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹14,499
# 4    2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹19,990
# 5    2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹15,999
# 6    1600 x 700$$pixel   1600 x 700$$pixel         5000 mAh   ₹8,974
# 7    2400 x 1080 Pixel   2400 x 1080 Pixel         5020 mAh  ₹17,999
# 8    2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹15,999
# 9   2400 x 1080$$pixel  2400 x 1080$$pixel                -  ₹14,247
# 10   1600 x 720$$pixel   1600 x 720$$pixel         5000 mAh   ₹8,048
# 11   2400 x 1080 Pixel   2400 x 1080 Pixel         5020 mAh  ₹17,999
# 12    1600 x 720 Pixel    1600 x 720 Pixel         5000 mAh   ₹7,499
# 13    1600 x 720 Pixel    1600 x 720 Pixel         5000 mAh   ₹7,499
# 14    1600 x 720 Pixel    1600 x 720 Pixel         5000 mAh   ₹7,499
# 15   720 x 1600$$pixel   720 x 1600$$pixel         5000 mAh   ₹6,999
# 16  2400 x 1080 PIxels                   -         4410 mAh  ₹43,999
# 17    1600 x 720 Pixel    1600 x 720 Pixel         5000 mAh   ₹7,499
# 18   1600 x 720$$pixel   1600 x 720$$pixel         5000 mAh   ₹8,047
# 19   1600 x 720$$pixel   1600 x 720$$pixel         5000 mAh   ₹7,877
# 20   720 x 1600$$pixel   720 x 1600$$pixel         5000 mAh   ₹7,049
# 21  2400 x 1080 PIxels                   -         4410 mAh  ₹43,999
# 22   2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹17,999
# 23   2400 x 1080 Pixel   2400 x 1080 Pixel         5000 mAh  ₹17,999
#
#                                                   URL
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/redmi-10-prime-phanto...
# 2   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 3   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 4   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 5   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 6   https://www.flipkart.com/redmi-10a-slate-grey-...
# 7   https://www.flipkart.com/redmi-note-10-pro-max...
# 8   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 9   https://www.flipkart.com/redmi-note-11-space-b...
# 10  https://www.flipkart.com/redmi-9a-sport-metall...
# 11  https://www.flipkart.com/redmi-note-10-pro-max...
# 12  https://www.flipkart.com/infinix-smart-6-light...
# 13  https://www.flipkart.com/infinix-smart-6-starr...
# 14  https://www.flipkart.com/infinix-smart-6-heart...
# 15  https://www.flipkart.com/redmi-9a-sport-carbon...
# 16  https://www.flipkart.com/google-pixel-6a-chalk...
# 17  https://www.flipkart.com/infinix-smart-6-polar...
# 18  https://www.flipkart.com/redmi-9a-sport-carbon...
# 19  https://www.flipkart.com/redmi-9a-sport-coral-...
# 20  https://www.flipkart.com/redmi-9a-sport-metall...
# 21  https://www.flipkart.com/google-pixel-6a-charc...
# 22  https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 23  https://www.flipkart.com/vivo-t1-44w-starry-sk...

# %%
df.to_csv("smartphones.csv")

# %%
driver.close()

# %% [markdown]
# # Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_1688/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = 'https://www.google.co.in/maps'
driver.get(url)
time.sleep(2)

# %%
City = input('Enter City name that has to be searched : ')
search_bar = driver.find_element(By.ID,'searchboxinput')
search_bar.click()
time.sleep(2)

search_bar.send_keys(City)


search_btn = driver.find_element(By.ID,"searchbox-searchbutton")
search_btn.click()
time.sleep(2)

try:
    url_str = driver.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))
except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City name that has to be searched : HYDERABAD
# URL Extracted:  https://www.google.co.in/maps/place/Hyderabad,+Telangana/@17.4876099,78.5092769,15z/data=!4m5!3m4!1s0x3bcb99daeaebd2c7:0xae93b78392bafbc2!8m2!3d17.385044!4d78.486671
# Latitude = 17.4876099, Longitude = 78.5092769

# %%
driver.close()

# %% [markdown]
# # Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_1688/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# %%
fund_button = driver.find_element(By.XPATH,"//li[@id='menu-item-51510']/a").get_attribute('href')
driver.get(fund_button)

#Empty Lists
fund_deals = {}
fund_deals['Date'] = []
fund_deals['Startup Name'] = []
fund_deals['Industry/Vertical'] = []
fund_deals['Sub_Vertical'] = []
fund_deals['Location'] = []
fund_deals['Investor'] = []
fund_deals['Investment Type'] = []
fund_deals['Amount(in USD)'] = []


for i in range(54,57):
    
    # scraping data of data
    date = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[2]".format(i))
    for d in date:
        fund_deals['Date'].append(d.text)
        
    # scraping data of startup name
    startup_name = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[3]".format(i))
    for name in startup_name:
        fund_deals['Startup Name'].append(name.text)
        
    
    #scraping data of industry or vertical
    industry = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[4]".format(i))
    for ind in industry:
        fund_deals['Industry/Vertical'].append(ind.text)
        
    
    #scraping data of sub-vertical
    sub_vertical = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[5]".format(i))
    for sv in sub_vertical:
        fund_deals['Sub_Vertical'].append(sv.text)
        
        
    # scraping data of location
    location = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[6]".format(i))
    for loc in location:
        fund_deals['Location'].append(loc.text)
        
        
    # scraping data of investor
    investor = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[7]".format(i))
    for invest in investor:
        fund_deals['Investor'].append(invest.text)
        
        
    # scraping data of investment type
    investment_type = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[8]".format(i))
    for invtype in investment_type:
        fund_deals['Investment Type'].append(invtype.text)
        
        
    # scraping data of amount
    amount = driver.find_elements(By.XPATH,"//table[@id='tablepress-{}']/tbody/tr/td[9]".format(i))
    for amt in amount:
        fund_deals['Amount(in USD)'].append(amt.text)

# %%
print(len(fund_deals['Date']),
len(fund_deals['Startup Name']),
len(fund_deals['Industry/Vertical']),
len(fund_deals['Sub_Vertical']),
len(fund_deals['Location']),
len(fund_deals['Investor']),
len(fund_deals['Investment Type']),
len(fund_deals['Amount(in USD)'] 
))
# Out:
# 24 24 24 24 24 24 24 24

# %%
fund_data = pd.DataFrame(fund_deals)
fund_data
# Out:
#           Date            Startup Name       Industry/Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  04/03/2021               DealShare              E-commerce
# 18  31/03/2021                Uniphore              Technology
# 19  30/03/2021                   Dunzo              E-commerce
# 20  30/03/2021                  BYJU’S                Edu-tech
# 21  23/03/2021             SkilloVilla                Edu-tech
# 22  25/03/2021                CityMall              E-commerce
# 23  26/03/2021                   DotPe                 FinTech
#
#                                          Sub_Vertical           Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                           Online shopping platform  Jaipur, Rajasthan
# 18            Conversational Service Automation (CSA)          Palo Alto
# 19                           Hyper-local delivery app          Bengaluru
# 20                                    Online tutoring          Bengaluru
# 21                Career and job-oriented upskilling.          Bengaluru
# 22       Social ecommerce and online grocery platform            Gurgaon
# 23  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17                                    Innoven Capital  Debt Financing
# 18                          Sorenson Capital Partners        Series D
# 19                          Krishtal Advisors Pte Ltd        Series E
# 20         MC Global Edtech, B Capital, Baron, others        Series F
# 21                              Titan Capital, others            Seed
# 22                                     Accel Partners        Series A
# 23                                               PayU        Series A
#
#    Amount(in USD)
# 0     1,80,00,000
# 1    6,172,258.50
# 2      30,000,000
# 3      15,000,000
# 4      16,000,000
# 5      15,000,000
# 6     100,000,000
# 7       4,000,000
# 8       2,500,000
# 9     250,000,000
# 10   2,747,045.20
# 11    1,50,00,000
# 12     75,000,000
# 13      4,773,958
# 14     55,000,000
# 15     15,000,000
# 16     18,000,000
# 17    250,000,000
# 18    140,000,000
# 19      8,000,000
# 20    460,000,000
# 21    300,000,000
# 22     11,000,000
# 23     27,500,000

# %%
fund_data.to_csv("trak_in.csv")

# %%
driver.close()

# %% [markdown]
# # Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_1688/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.digit.in/"
driver.get(url)
time.sleep(2)

# %%
best_gam_laptops = driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(3)

# %%
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
#Graph_proc = []
Price = []

# %%
laptop_name = driver.find_elements(By.XPATH,"//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)
    
# data of operating system
try:
    op_sys = driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#data of display of the Laptop
try:
    display = driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


# data of processor
try:
    processor = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass


#data of memory
try:
    memory = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass


#  data of weight
try:
    weight = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for wgt in weight:
        Weight.append(wgt.text)
except NoSuchElementException:
    pass


# data of dimensions
try:
    dimension = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass



#data of price
try:
    price = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹ ','Rs'))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),
len(Operating_sys),
len(Display),
len(Processor),
len(Memory),
len(Weight),
len(Dimensions),
len(Price))
# Out:
# 10 10 10 10 10 10 10 10

# %%
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating System'] =Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Weight'] = Weight
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#                                      Laptop Name    Operating System  \
# 0                           MSI TITAN GT77-12UHS  WINDOWS 11 HOME OS
# 1                               ALIENWARE X17 R2  WINDOWS 11 HOME OS
# 2          ACER PREDATOR TRITON 500 SE PT516-52S  WINDOWS 11 HOME OS
# 3                        OMEN BY HP (16-B1371TX)  WINDOWS 11 HOME OS
# 4  ACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0  WINDOWS 11 HOME OS
# 5                     MSI DELTA 15 (A5EFK-083IN)  WINDOWS 11 HOME OS
# 6                        OMEN BY HP (16-C0141AX)  WINDOWS 11 HOME OS
# 7              LENOVO LEGION 5I PRO (82RF00MGIN)  WINDOWS 11 HOME OS
# 8  ALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN  WINDOWS 11 HOME OS
# 9               LENOVO SLIM 7 GEN 6 (82K8002JIN)  WINDOWS 11 HOME OS
#
#                        Display        Processor                       Memory  \
# 0  17.3" (3840 X 2160) DISPLAY  Windows 11 Home    64 GB DDR5 RAM & 2 TB SSD
# 1    17.3" (1920X1080) DISPLAY  Windows 11 Home    32 GB DDR5 RAM & 1 TB SSD
# 2    16" (2560 X 1600) DISPLAY  Windows 11 Home    32 GB DDR5 RAM & 2 TB SSD
# 3  16.1" (2560 X 1440) DISPLAY  Windows 11 Home     8 GB DDR5 RAM & 1 TB SSD
# 4  15.6" (2560 X 1440) DISPLAY  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 5  15.6" (1920 X 1080) DISPLAY  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
# 6  16.1" (2560 X 1440) DISPLAY  Windows 11 Home   16 GB DDR4 RAM & 1 TB NVMe
# 7    16" (2560 X 1600) DISPLAY  Windows 11 Home    16 GB DDR5 RAM & 1 TB SSD
# 8  15.6" (1920 X 1080) DISPLAY  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 9         15.6 MP | NA DISPLAY  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
#
#                                               Weight  \
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 1  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti, Graphic...
# 2  8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 3   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 4    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5       10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 6      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 7    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
#
#                                           Dimensions      Price
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight        N/A
# 1  399.23 x 299.57 x 14.75 mm dimension & 3.02 kg...  Rs389,990
# 2      358 x 262 x 19.9 mm dimension & 2.4 kg weight  Rs300,000
# 3       369 x 248 x 23 mm dimension & 2.32 kg weight  Rs197,000
# 4      363 x 255 x 23.9 mm dimension & 2.4 kg weight  Rs172,999
# 5        357 x 247 x 19 mm dimension & 1.9 kg weight  Rs188,990
# 6    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight  Rs129,899
# 7  359.9 x 264.4 x 19.9 mm dimension & 2.5 kg weight  Rs230,890
# 8  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...  Rs144,990
# 9        356 x 252 x 16 mm dimension & 1.9 kg weight  Rs135,490

# %%
Gaming_Laptop.to_csv("Gaming_Laptops.csv")

# %%
driver.close()

# %% [markdown]
# # Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_1688/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.forbes.com/?sh=41bd46d2254c"
driver.get(url)

# %%
opt_btn = driver.find_element(By.XPATH,"//div[@class='header__left']//button")
opt_btn.click()
time.sleep(3)

blns = driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[3]/ul/li[1]")
blns.click()
time.sleep(3)
#select world billionaire
bln_list = driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
bln_list.click()
time.sleep(4)

# %%
Rank = []
Person_Name = []
Net_worth = []
Age = []
Citizenship = []
Source = []
Industry = []


while(True):
    
    # data of rank of the billionaires
    rank_tag = driver.find_elements(By.XPATH,"//div[@class='rank']")
    for rank in rank_tag:
        Rank.append(rank.text)
    time.sleep(1)
    
    
 
    # data  of names of the billionaires
    name_tag = driver.find_elements(By.XPATH,"//div[@class='personName']/div")
    for name in name_tag:
        Person_Name.append(name.text)
    time.sleep(1)
    
    
    # data of age of the billionaires
    age_tag = driver.find_elements(By.XPATH,"//div[@class='age']/div")
    for age in age_tag:
        Age.append(age.text)
    time.sleep(1)
    
    
    # data of citizenship of the billionaires
    cit_tag = driver.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
    for cit in cit_tag:
        Citizenship.append(cit.text)
    time.sleep(1)
    
    
    # data of source of income of the billionaires
    sour_tag = driver.find_elements(By.XPATH,"//div[@class='source']")
    for sour in sour_tag:
        Source.append(sour.text)
    time.sleep(1)
    
    
    # data of industry of the billionaires
    ind_tag = driver.find_elements(By.XPATH,"//div[@class='category']//div")
    for ind in ind_tag:
        Industry.append(ind.text)
    time.sleep(1)
    
    
    # data of net_worth of billionaires
    net_tag = driver.find_elements(By.XPATH,"//div[@class='netWorth']/div")
    for net in net_tag:
        Net_worth.append(net.text)
    time.sleep(1)
    
    
    # clicking on next button
    try:
        next_button = driver.find_element(By.XPATH,"//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break

# %%
print(len(Rank),
len(Person_Name),
len(Net_worth),
len(Age),
len(Citizenship),
len(Source),
len(Industry))
# Out:
# 200 200 200 200 200 200 200

# %%
Billionaires = pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Name'] = Person_Name
Billionaires['Net Worth'] = Net_worth
Billionaires['Age'] = Age
Billionaires['Citizenship'] = Citizenship
Billionaires['Source'] = Source
Billionaires['Industry'] = Industry
Billionaires
# Out:
#      Rank                      Name Net Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %%
Billionaires.to_csv('Forbes_Billionaires.csv')

# %%
driver.close()

# %% [markdown]
# # Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_11864/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
search_bar = driver.find_element(By.XPATH,"//div[@class='ytd-searchbox-spt']/input")
search_bar.send_keys("PASOORI")   
time.sleep(2)

# %%
search_btn = driver.find_element(By.ID,"search-icon-legacy")
search_btn.click()
time.sleep(2)

# %%
video = driver.find_element(By.XPATH,"//yt-formatted-string[@class='style-scope ytd-video-renderer']")
video.click()

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []


cm = driver.find_elements(By.ID,"content-text")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)
time.sleep(4)



tm = driver.find_elements(By.XPATH,"//a[contains(text(),'ago')]")
for i in tm:
    Time.append(i.text)
    
for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(4)


like = driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])

# %%
print(len(comments),len(No_of_Likes))
# Out:
# 180 180

# %%
Youtube = pd.DataFrame({})
Youtube['Comment'] = comments[:500]
#Youtube['Comment Time'] = comment_time[:500]
Youtube['Comment Upvotes'] = No_of_Likes[:500]
Youtube
# Out:
#                                                Comment Comment Upvotes
# 0    This song is pulling off all over the Australi...            1.5K
# 1    OH MANNNN 3:55  THIS PART GIVES ME GOOOOOOSEBU...              97
# 2    Best wishes to my Pakistan brothers and sister...             194
# 3    I m so happy to see the positive comments from...              73
# 4    Found this song 2 months ago and I have been l...               7
# ..                                                 ...             ...
# 175  great music loved it bro... love from india......              11
# 176     Shae gills voice another level  \nLove from 🇮🇳               2
# 177  Heard it almost for 10 times best song i heard...
# 178  If you are recommended this music by Youtube, ...               1
# 179  this is the first time i listened to this song...
#
# [180 rows x 2 columns]

# %%
Youtube.to_csv('Youtube.csv')

# %%
driver.close()

# %% [markdown]
# # Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(5)
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_11864/425545205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.hostelworld.com/"
driver.get(url)
time.sleep(5)

# %%
search = driver.find_element(By.XPATH,'//*[@id="search-input-field"]')
search.send_keys("London")

#select london
london = driver.find_element(By.XPATH,'//*[@id="location-text-input-field"]')
#london.click()
time.sleep(5)


# do click on search button
search_btn = driver.find_element(By.ID,'search-button')
search_btn.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_11864/1507235901.py in <module>
# ----> 1 search = driver.find_element(By.XPATH,'//*[@id="search-input-field"]')
#       2 search.send_keys("London")
#       3
#       4 #select london
#       5 london = driver.find_element(By.XPATH,'//*[@id="location-text-input-field"]')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     855             value = '[name="%s"]' % value
#     856
# --> 857         return self.execute(Command.FIND_ELEMENT, {
#     858             'using': by,
#     859             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="search-input-field"]"}
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00BE6463+2188387]
# 	Ordinal0 [0x00B7E461+1762401]
# 	Ordinal0 [0x00A93D78+802168]
# 	Ordinal0 [0x00AC1880+989312]
# 	Ordinal0 [0x00AC1B1B+989979]
# 	Ordinal0 [0x00AEE912+1173778]
# 	Ordinal0 [0x00ADC824+1099812]
# 	Ordinal0 [0x00AECC22+1166370]
# 	Ordinal0 [0x00ADC5F6+1099254]
# 	Ordinal0 [0x00AB6BE0+945120]
# 	Ordinal0 [0x00AB7AD6+948950]
# 	GetHandleVerifier [0x00E871F2+2712546]
# 	GetHandleVerifier [0x00E7886D+2652765]
# 	GetHandleVerifier [0x00C7002A+520730]
# 	GetHandleVerifier [0x00C6EE06+516086]
# 	Ordinal0 [0x00B8468B+1787531]
# 	Ordinal0 [0x00B88E88+1805960]
# 	Ordinal0 [0x00B88F75+1806197]
# 	Ordinal0 [0x00B91DF1+1842673]
# 	BaseThreadInitThunk [0x76576739+25]
# 	RtlGetFullPathName_UEx [0x770F8FEF+1215]
# 	RtlGetFullPathName_UEx [0x770F8FBD+1165]

# %%
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description = []
url = []

# %%
for i in driver.find_elements(By.XPATH,"//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    #fetching hostel name
    try:
        name = driver.find_elements(By.XPATH,"//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
    #fetching distance from city centre
    
    try:
        dist = driver.find_elements(By.XPATH,"//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements(By.XPATH,"//div[@class='prices-col']"):
    #fetch privates from price
        try:
            pvt_price = driver.find_element(By.XPATH,"//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
    #fetching dorms from price
    for i in driver.find_elements(By.XPATH,"//div[@class='prices-col']"):
        try:
            dorms = driver.find_element(By.XPATH,"//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            #fetching facilities
    try:
        fac1 = driver.find_elements(By.XPATH,"//div[@class='has-wifi']")
        fac2 = driver.find_elements(By.XPATH,"//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
    #lets fetch url of each hostel
    p_url = driver.find_elements(By.XPATH,"//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    #lets click on show more button for description
    try:
        driver.find_element(By.XPATH,"//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    #fetching ratings
    try:
        rat = driver.find_element(By.XPATH,"//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
    #fetching total reviews
        
    try:
        rws = driver.find_element(By.XPATH,"//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        #fetch overall review
    try:
        overall_rw = driver.find_element(By.XPATH,"//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
    #fetch property description 
    try:
        disc = driver.find_element(By.XPATH,"//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_11864/758932551.py in <module>
#      46         product_url.append(i.get_attribute('href'))
#      47
# ---> 48 for i in product_url:
#      49     driver.get(i)
#      50     time.sleep(3)
#
# NameError: name 'product_url' is not defined

# %%
dff = pd.DataFrame({})
dff['Hostel_Name'] = hostel_name
dff['Distance fron city centre'] = distance
dff['Ratings'] = rating
dff['Total_reviews'] = reviews
dff['Overall Reviews'] = over_all
dff['Privates from price'] = pvt_prices
dff['Dorms from price'] = dorms_price
dff['Facilities'] = facilities[:83]
dff['Description'] = description

# %%
dff
# Out:
# Empty DataFrame
# Columns: [Hostel_Name, Distance fron city centre, Ratings, Total_reviews, Overall Reviews, Privates from price, Dorms from price, Facilities, Description]
# Index: []

# %%
dff.to_csv("London_Hostels.csv")
